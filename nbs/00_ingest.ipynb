# %% [markdown]
# # Defining Hamilton Drivers
# > Using functions from "transformations"

# %%
import nbdev

# %%
import importlib
import pandas as pd
from hamilton import driver

# %%
# %load_ext autoreload
# %autoreload 2
# %aimport rent
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from rent import transformations

# %% [markdown]
# # Read DataFrame

# %%
import pandas as pd

# %%
k=5

# %%
df = pd.read_csv("../data/housing_train.csv", nrows=k)

# %%
df.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'type', 'sqfeet', 'beds',
#        'baths', 'cats_allowed', 'dogs_allowed', 'smoking_allowed',
#        'wheelchair_access', 'electric_vehicle_charge', 'comes_furnished',
#        'laundry_options', 'parking_options', 'image_url', 'description', 'lat',
#        'long', 'state'],
#       dtype='object')

# %%
df.head()
# Out:
#            id                                                url      region  \
# 0  7039061606  https://bham.craigslist.org/apa/d/birmingham-h...  birmingham
# 1  7041970863  https://bham.craigslist.org/apa/d/birmingham-w...  birmingham
# 2  7041966914  https://bham.craigslist.org/apa/d/birmingham-g...  birmingham
# 3  7041966936  https://bham.craigslist.org/apa/d/birmingham-f...  birmingham
# 4  7041966888  https://bham.craigslist.org/apa/d/birmingham-2...  birmingham
#
#                     region_url  price       type  sqfeet  beds  baths  \
# 0  https://bham.craigslist.org   1195  apartment    1908     3    2.0
# 1  https://bham.craigslist.org   1120  apartment    1319     3    2.0
# 2  https://bham.craigslist.org    825  apartment    1133     1    1.5
# 3  https://bham.craigslist.org    800  apartment     927     1    1.0
# 4  https://bham.craigslist.org    785  apartment    1047     2    1.0
#
#    cats_allowed  ...  wheelchair_access  electric_vehicle_charge  \
# ...

# %% [markdown]
# # Define Production Inputs

# %%
prod_cols = ['region', 'type', 'sqfeet', 'beds', 'baths', 'cats_allowed', 
             'dogs_allowed', 'smoking_allowed', 'wheelchair_access', 
             'electric_vehicle_charge', 'comes_furnished', 'laundry_options', 
             'parking_options', 'lat', 'long', 'state']

# %%
nbdev.nbdev_export()

# %%
dr = driver.Driver({}, transformations)
outputs = [transformations.load_data, transformations.is_half_bath]
result = dr.execute(
    outputs,
    inputs={"path" : "../data/housing_train.csv", "nrows" : 5}
  #inputs=df.to_dict(orient="series")
)

# %%
result
# Out:
#    load_data.id                                      load_data.url  \
# 0    7039061606  https://bham.craigslist.org/apa/d/birmingham-h...
# 1    7041970863  https://bham.craigslist.org/apa/d/birmingham-w...
# 2    7041966914  https://bham.craigslist.org/apa/d/birmingham-g...
# 3    7041966936  https://bham.craigslist.org/apa/d/birmingham-f...
# 4    7041966888  https://bham.craigslist.org/apa/d/birmingham-2...
#
#   load_data.region         load_data.region_url  load_data.price  \
# 0       birmingham  https://bham.craigslist.org             1195
# 1       birmingham  https://bham.craigslist.org             1120
# 2       birmingham  https://bham.craigslist.org              825
# 3       birmingham  https://bham.craigslist.org              800
# 4       birmingham  https://bham.craigslist.org              785
#
#   load_data.type  load_data.sqfeet  load_data.beds  load_data.baths  \
# 0      apartment              1908               3              2.0
# ...

# %%
dr.display_all_functions()
